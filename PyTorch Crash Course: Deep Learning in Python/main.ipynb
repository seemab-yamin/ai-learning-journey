# %% [markdown]
# # PyTorch Crash Course: Deep Learning in Python
#
# https://youtu.be/uq7sbUlIDR8

# %%
import torch

# %%
torch.cuda.is_available()
# Out:
# False

# %%
torch.cuda.device_count()
# Out:
# 0

# %%
# run if have cuda device to get name
# torch.cuda.get_device_name(0)

# %%
torch.cuda.device(0)

# %% [markdown]
# ## Tensors

# %%
import numpy as np

arr = np.array([[1, 2, 3, 5], [1, 2, 3, 5]])
arr
# Out:
# array([[1, 2, 3, 5],
#        [1, 2, 3, 5]])

# %%
tensor = torch.Tensor([[1, 2, 3, 5], [1, 2, 3, 5]])
tensor, tensor.shape
# Out:
# (tensor([[1., 2., 3., 5.],
#          [1., 2., 3., 5.]]),
#  torch.Size([2, 4]))

# %%
arr * 5
# Out:
# array([[ 5, 10, 15, 25],
#        [ 5, 10, 15, 25]])

# %%
tensor * 5
# Out:
# tensor([[ 5., 10., 15., 25.],
#         [ 5., 10., 15., 25.]])

# %%
arr.sum(), tensor.sum()
# Out:
# (np.int64(22), tensor(22.))

# %%
tensor = torch.from_numpy(arr)
tensor # will be integers because created from numpy array
# Out:
# tensor([[1, 2, 3, 5],
#         [1, 2, 3, 5]])

# %%
np.ones([2, 4]), torch.ones([1, 2])
# Out:
# (array([[1., 1., 1., 1.],
#         [1., 1., 1., 1.]]),
#  tensor([[1., 1.]]))

# %%
np.random.random((2, 4)), torch.rand((1, 2))
# Out:
# (array([[0.38190054, 0.3988076 , 0.77035688, 0.19428939],
#         [0.20628627, 0.29686629, 0.25130987, 0.06290445]]),
#  tensor([[0.3276, 0.7559]]))

# %%
arr.shape, tensor.shape, arr.dtype, tensor.dtype, torch.device
# Out:
# ((2, 4), torch.Size([2, 4]), dtype('int64'), torch.int64, torch.device)

# %%
arr.to_device('cuda')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[43], line 1
# ----> 1 arr.to_device('cuda')
#
# ValueError: Unsupported device: cuda. Only 'cpu' is accepted.

# %%
# run if have cuda configured
# tensor = tensor.to('cuda')
# tensor.sum() # now sum will be calcualted on GPU

# this will give error if tensor is on GPU
# tensor.numpy()

# %%
tensor.cpu().numpy()
# Out:
# array([[1, 2, 3, 5],
#        [1, 2, 3, 5]])

# %%
# 11 Minutes Dones
